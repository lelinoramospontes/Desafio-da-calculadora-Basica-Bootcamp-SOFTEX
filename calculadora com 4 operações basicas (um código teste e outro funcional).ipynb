# %%
 #Definindo as váriavies da função    
def calculadora(a,b,operacao):            
        if operacao == "1": return  a + b  #Retornando a operação matemática escolhida       
        elif operacao == "2": return  a - b
        elif operacao == "3":  return  a * b
        elif operacao == "4":  return  a / b
#Inciando o laço de repetição
op_Correta=True
while (op_Correta==True): 
    print("\nEscolha um número conforme a lista para realizar a operação") #Mostrando a opções das operações
    print("1- Soma")
    print("2- Subtração")
    print("3- Multiplicação")
    print("4-Divisão")
    print("0 - Sair")
    operacao = int(input("\nDigite a operação a realizar (+,-,*,ou /):"))  #Entra dos dados           
    if operacap>=1 and operacao<=4:                    
        a= float(input("\nDigite o primeiro número:")) #Entra dos dados
        b=float(input("\nDigite o segundo número:")) #Entra dos dados

        resultado = calculadora(a,b,operacao)   #Resultado da função            
        print("\nO resultado é:",resultado)

    elif operacao== 0:                        #saida do laço de repetição
        print("Saindo")
        op_Correta= False
        
    else:print("Essa opção não existe, digite 1,2,3 ou 4:") #Condicional de erro.

# %%
#Inciando o loop com while, para que ocorra a repetição do codigo infinitamente
op_Correta = True
while (op_Correta==True):
    print("\nEscolha um número conforme a lista para realizar a operação") #Mostrando a opções das operações
    print("+ Soma")
    print("- Subtração")
    print("* Multiplicação")
    print("/-Divisão")
    print("s - Sair")
    operacao = (input("\nDigite a operação a realizar (+,-,*,ou /):")) #Entrada de dados com a operação desejada
    
    def calculadora(a,b,operacao):                                   # Defindindo a função calculadora
        a=float(input("\nDigite o primeiro número: "))               #Entrada de dados com o primeiro número desejado
        b=float(input("Digite o segundo número: "))                  #Entrada de dados com o segundo número desejado
#Retornando a operação matemática escolhida                                                 
        if operacao == "+": return a+b                               
        if operacao == "-": return a-b
        if operacao == "*": return a*b
        if operacao == "/": return a/b
        
#Condicional de erro, caso o usuário digite uma opção incorreta  
        else:                                                       
            print("\nOperação inválida!")
            operacao = (input("Você deve digitar: (+,-,*,ou /)"))
            a=float(input("\nDigite o primeiro número: "))
            b=float(input("Digite o segundo número: "))
            if operacao == "+": return a+b 
            if operacao == "-": return a-b
            if operacao == "*": return a*b
            if operacao == "/": return a/b
            
 # Condicional para interromper o loop de repetição     
    if operacao=="s":
        print("Saindo")
        op_Correta = False
        break
# Mostrando o resultado da operação matemática escolhida pelo usuário.
    resultado = calculadora(a,b,operacao)
    print("O resultado é:",resultado)
